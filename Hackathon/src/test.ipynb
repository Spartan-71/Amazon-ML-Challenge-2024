# %% [markdown]
# ### Basic library imports

# %%
import os
import pandas as pd

# %% [markdown]
# ### Read Dataset

# %%
DATASET_FOLDER = '../dataset/'
train = pd.read_csv(os.path.join(DATASET_FOLDER, 'train.csv'))
test = pd.read_csv(os.path.join(DATASET_FOLDER, 'test.csv'))
sample_test = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test.csv'))
sample_test_out = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test_out.csv'))

# %% [markdown]
# ### Run Sanity check using src/sanity.py

# %%
# !python sanity.py --test_filename ../dataset/sample_test.csv --output_filename ../dataset/sample_test_out.csv
# Out:
# {'millivolt', 'cubic inch', 'kilogram', 'quart', 'gram', 'metre', 'decilitre', 'volt', 'cup', 'pound', 'milligram', 'ounce', 'millilitre', 'fluid ounce', 'inch', 'centimetre', 'microlitre', 'kilovolt', 'litre', 'pint', 'microgram', 'imperial gallon', 'millimetre', 'gallon', 'ton', 'foot', 'centilitre', 'kilowatt', 'watt', 'cubic foot', 'yard'}
# Parsing successfull for file: ../dataset/sample_test_out.csv

# %%
# !python sanity.py --test_filename ../dataset/sample_test.csv --output_filename ../dataset/sample_test_out_fail.csv
# Out:
# {'millilitre', 'yard', 'kilovolt', 'pint', 'volt', 'watt', 'cup', 'fluid ounce', 'microlitre', 'inch', 'microgram', 'metre', 'centimetre', 'kilogram', 'centilitre', 'quart', 'gallon', 'pound', 'ounce', 'milligram', 'kilowatt', 'decilitre', 'millimetre', 'millivolt', 'cubic foot', 'ton', 'imperial gallon', 'gram', 'foot', 'cubic inch', 'litre'}
# Error: Invalid format in lbs

# %% [markdown]
# ### Download images

# %%
from utils import download_images
download_images(train['image_link'], '../images')
# Out:
#   1%|          | 2979/263859 [01:01<1:29:29, 48.59it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /usr/lib/python3.12/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 from utils import download_images
# ----> 2 download_images(train['image_link'], '../images')
#
# File ~/Amazon-ML-Challenge-2024/student_resource 3/src/utils.py:77, in download_images(image_links, download_folder, allow_multiprocessing)
#      73 download_image_partial = partial(
#      74     download_image, save_folder=download_folder, retries=3, delay=3)
#      76 with multiprocessing.Pool(64) as pool:
# ---> 77     list(tqdm(pool.imap(download_image_partial, image_links), total=len(image_links)))
#      78     pool.close()
#      79     pool.join()
#
# File ~/Amazon-ML-Challenge-2024/.venv/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /usr/lib/python3.12/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
assert len(os.listdir('../images')) > 0

# %%
rm -rf ../images

# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt
from PIL import Image

# Load an image from file
image_path = '../images/7107fyOBRRL.jpg'
image = cv2.imread(image_path)

# Convert the image to RGB (for displaying with matplotlib)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(image_rgb)
plt.title("Sample Image")
plt.axis('off')  # Hide axes
plt.show()

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Optional: Apply thresholding to preprocess the image
_, thresh_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

# Use pytesseract to do OCR on the image
text = pytesseract.image_to_string(gray_image)
# Print the extracted text
print("Extracted Text:")
print(text)
# Out:
# Extracted Text:
# =
# a
# ai
# =
# a
# °
# 3
# SG
#
# WOW
#
# ————S
#
# LIFE SCIENCE
#
# MILK THISTLE
#
# CAPSULES
#
# BEST QUALITY NATURAL NUTRITION
# FOR YOUR WELLNESS
#
# Rich in Silymarin - The Antioxidant for Liver Health
#
# Supports liver health
# ¢ Supports healthy cholesterol levels
# ° Supports healthy blood sugar levels
#
# MILK THISTLE
# MILK THISTLE 600 mo sz
#
# BEST QUALITY NATURAL NUTRITION =
# FOR YOUR WELLNESS Mme
#
# Rich in Silymarin - The Antioxidant for Liver Health 60 Vegetarian Capsules
# Nutraceutical
#
# GOOD HEALTH
#
# =
#
# WOW
#
# LIFE SCIENCE
#
# Supports liver health
#
# Supports healthy
# cholesterol levels
#
# Supports healthy
# blood sugar levels
#
# \ 60 Vegetarian Capsules ¢ Nutraceutical

# %%
import cv2
import numpy as np

# Load image and convert to grayscale
image = cv2.imread('image_path.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply binary thresholding
_, binary_image = cv2.threshold(gray_image, 150, 255, cv2.THRESH_BINARY_INV)

# Find contours
contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a blank mask of the same size as the image
mask = np.zeros_like(image)

# Draw the contours on the mask
cv2.drawContours(mask, contours, -1, (255, 255, 255), thickness=cv2.FILLED)

# Apply the mask to the original image
masked_image = cv2.bitwise_and(image, mask)

# Display the result
cv2.imshow('Masked Image', masked_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [ WARN:0@0.024] global loadsave.cpp:241 findDecoder imread_('image_path.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Load image and convert to grayscale
#       5 image = cv2.imread('image_path.jpg')
# ----> 6 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       8 # Apply binary thresholding
#       9 _, binary_image = cv2.threshold(gray_image, 150, 255, cv2.THRESH_BINARY_INV)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
string = "anish"
print(string[:-2])
# Out:
# ani
